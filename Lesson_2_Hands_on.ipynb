# %% [markdown]
# # Exercise 1: Creating Variables

# %%
name = "meso"
age = 25
country = "nigeria"
print(name)
print(age)
print(country)
# Out:
# meso
# 25
# nigeria

# %% [markdown]
# # Exercise 2: Salary Calculation

# %%
Basic_Salary = 180000
Bonus = 35000
Total_Salary = Basic_Salary + Bonus
print(Basic_Salary)
print(Bonus)
print(Total_Salary)
# Out:
# 180000
# 35000
# 215000

# %% [markdown]
# # Exercise 3: User Input

# %%
name = input("Enter Your name: ")
language = input("Enter Your favourite progamming language: ")
print("Hello", name)
print("your favourite programming language is", language)
# Out:
# Enter Your name:  Meso
# Enter Your favourite progamming language:  Python
# Hello Meso
# your favourite programming language is Python

# %% [markdown]
# # Exercise 4: Working with Data Types

# %%
age = 10
average = 10.5
name = "Timothy"
in_valid = True
print(type(age))
print(type(average))
print(type(name))
print(type(in_valid))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# # Exercise 5: Dynamic Typing

# %%
age = 14
age = "Hello"
print(type(age))
# Out:
# <class 'str'>

# %% [markdown]
# # Mini Project: Student Imformation Card

# %%
name = input("full name: ")
age = input("age: ")
course = input("course tittle: ")
country = input("country: ")


print("Name:", name)
print("Age:", age)
print("Course:", course)
print("Country:", country)


print("name:", type(name))
print("age:", type(age))
print("course:", type(course))
print("country:", type(country))
# Out:
# full name:  Blessing Ehilawa
# age:  20
# course tittle:  Python
# country:  Nigeria
# Name: Blessing Ehilawa
# Age: 20
# Course: Python
# Country: Nigeria
# name: <class 'str'>
# age: <class 'str'>
# course: <class 'str'>
# country: <class 'str'>

# %% [markdown]
# # Bonus Challenge

# %%
Age = "Meso" 
Age = 25
print(type(Age))
# Out:
# <class 'int'>
