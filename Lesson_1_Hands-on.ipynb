# %% [markdown]
# # Hands-on Practice excercise

# %% [markdown]
# # Exercise 1: Printing Text

# %%
print("Hello, World")
print("My name is Blessing")
print("I am learning Python")
print("Progamming is exciting")
# Out:
# Hello, World
# My name is Blessing
# I am learning Python
# Progamming is exciting

# %% [markdown]
# # Exercise 2: Multiple Print Statement

# %%
print("My favourite food is beans")
print("We love movie")
print("I love football")
print("My favourite color is blue")
# Out:
# My favourite food is beans
# We love movie
# I love football
# My favourite color is blue

# %% [markdown]
# # Exercise 3: Python Calculator

# %%
print(15 + 5)
print(30 - 12)
print(9 * 8)
print(72 + 9)
print(18 % 5)
print(10 // 3)
print(5 ** 2)
# Out:
# 20
# 18
# 72
# 81
# 3
# 3
# 25

# %% [markdown]
# # Exercise 4: Understanding Comments

# %%
print("python")   # Display the progamming language
print("progamming")   # Display the subject
print("lesson one")   # Display the title
# Out:
# python
# progamming
# lesson one

# %% [markdown]
# # Exercise 5: Mini Challenge

# %%
print("Ehilawa Blessing") # print my name 
print("Data Analyst") # print my dream career 
print("Nigeria") # print my country
print("25 + 75") # calculate 25 + 75
# Out:
# Ehilawa Blessing
# Data Analyst
# Nigeria
# 25 + 75
