# %%
statement = "the language 'Python' is named after monty python"

# %%
sentence = ' python is "the king of programming",'

# %%
message = """
welcome to my home!
we are excited to see you.
happy learning!
"""
print(message)
# Out:
# welcome to my home!
# we are excited to see you.
# happy learning!

# %% [markdown]
# # Lesson 5A: hands-on exercise

# %% [markdown]
# # task 1: customer registration system

# %%
customer_name = "Timothy"
email = "timothy@gmail.com"
phone = "+23490775558"
country = "Nigeria"
occupation = "Data analyst coach"
print("customer_name:", customer_name)
print("email:", email)
print("phone:", phone)
print("country:", country)
print("occupation:", occupation)
# Out:
# customer_name: Timothy
# email: timothy@gmail.com
# phone: +23490775558
# country: Nigeria
# occupation: Data analyst coach

# %% [markdown]
# # Task 2:hospital patient record

# %%
patient_name = 'ola'
doctor = 'maya james'
diagnosis = 'fever'
blood_group = 'O+'
hospital = 'general city hospital'


print('===============================')
print('PATIENT RECORD')
print('===============================')

print('patient_name:', patient_name)
print('doctor:', doctor)
print('diagnosis:', diagnosis)
print('hospital:', hospital)

print('===============================')
# Out:
# ...
# PATIENT RECORD
# ...
# patient_name: ola
# doctor: maya james
# diagnosis: fever
# hospital: general city hospital
# ...

# %%
patient_record = """
patient_name: ola
doctor: maya james
diagnosis: fever
hospital: general city hospital
"""
print(patient_record)
# Out:
# patient_name: ola
# doctor: maya james
# diagnosis: fever
# hospital: general city hospital

# %% [markdown]
# # task 3: AI prompt

# %%
prompt = '''
You are an \'AI Assistant\'.
Analyze customer feedback.
Identify common cpmplaints.
Provide recommendations.
Generates a summary report.
'''
print(prompt)
# Out:
# You are an 'AI Assistant'.
# Analyze customer feedback.
# Identify common cpmplaints.
# Provide recommendations.
# Generates a summary report.

# %% [markdown]
# # bonus challenge

# %%
prompt = '''
You are an \'AI Assistant\'.
Analyze customer feedback.
Identify common cpmplaints.
Provide recommendations.
Generates a summary report.
format the output into clear bullet points with an executive summary at the top
'''
print(prompt)
# Out:
# You are an 'AI Assistant'.
# Analyze customer feedback.
# Identify common cpmplaints.
# Provide recommendations.
# Generates a summary report.
# format the output into clear bullet points with an executive summary at the top

# %% [markdown]
# # real world case study project
#
# # customer feedback management system

# %%
customer_name = 'Sarah Johnson'
product_name = 'Wireless Mouse'
category = 'Computer Accessories'
rating = '5 Star'
customer_review = (
    'The product arrived on time, was eassy to  install,'
                   'and exceeded my expectations.'
                    'I would definitely recommend it to others.')

print('customer_name:', customer_name)
print('product_name:' , product_name)
print('category:' , category)
print('rating:' , rating)
print('customer_review:' ,customer_review)
# Out:
# customer_name: Sarah Johnson
# product_name: Wireless Mouse
# category: Computer Accessories
# rating: 5 Star
# customer_review: The product arrived on time, was eassy to  install,and exceeded my expectations.I would definitely recommend it to others.

# %%
feedback_report = """
customer_name: Sarah Johnson
product_name: Wireless Mouse
category: Computer Accessories
rating: 5 Star"""

customer_review = """
The product arrived on time, 
was eassy to install, 
and exceeded my expectations.
I would definitely recommend it to others.
"""


print("=====================================")
print("CUSTOMER FEEDBACK REPORT")
print("=====================================")

print(feedback_report)

print("---------------------------------------")
print("customer_review")
print("---------------------------------------")
print(customer_review)
print("---------------------------------------")
print("Thank you for your feedback!")
print("---------------------------------------")
# Out:
# ...
# CUSTOMER FEEDBACK REPORT
# ...
#
# customer_name: Sarah Johnson
# product_name: Wireless Mouse
# category: Computer Accessories
# rating: 5 Star
# ---------------------------------------
# customer_review
# ---------------------------------------
#
# The product arrived on time,
# was eassy to install,
# and exceeded my expectations.
# I would definitely recommend it to others.
#
# ---------------------------------------
# Thank you for your feedback!
# ---------------------------------------
