# %% [markdown]
# # LESSON 3: HANDS-ON EXERCISE

# %% [markdown]
# # Question 1: employee payroll & bonus eligibility

# %%
salary = 180000
bonus = 45000
total_salary = salary + bonus
print(total_salary)

premium_salary = total_salary >=  225000
print(premium_salary)
# Out:
# 225000
# True

# %% [markdown]
#  # Question 2: student performance evaluation

# %%
python = 72
sql = 65
excel = 80
power_bi = 75
total_score = python + sql + excel + power_bi
average_score = total_score / 4
student_passed = total_score >= 70
print(total_score)
print(average_score)
print(student_passed)
# Out:
# 292
# 73.0
# True

# %% [markdown]
# # Question 3: Inventory management system

# %%
initial_stock = 250
sold = 85
remaining_stock = initial_stock - sold
reorder = remaining_stock < 200
print(remaining_stock)
print(reorder)
# Out:
# 165
# True

# %% [markdown]
# # Question 4: Banking withdrawal checker

# %%
account_balance = 520000
withdraw = 150000
remaining_balance = account_balance - withdraw
approved = account_balance >= withdraw
print(remaining_balance)
print(approved)
# Out:
# 370000
# True

# %% [markdown]
# # Bonus challenge: Smart shopping discount calculator

# %%
laptop_bag = 18500
wireless_mouse = 12000
keyboard = 24500
usb_drive = 5000
total_purchase = laptop_bag + wireless_mouse + keyboard + usb_drive
qualify_for_discount = total_purchase >= 50000
discount_amount = total_purchase * 0.10
finale_amount = total_purchase - discount_amount
print(total_purchase)
print(qualify_for_discount)
print(discount_amount)
print(finale_amount)
# Out:
# 60000
# True
# 6000.0
# 54000.0
